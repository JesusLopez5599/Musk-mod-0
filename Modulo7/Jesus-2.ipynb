# %%
pip install --upgrade pip
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pip in /Users/jesuslopezguerrero/Library/Python/3.9/lib/python/site-packages (25.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install Flask
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: Flask in /Users/jesuslopezguerrero/Library/Python/3.9/lib/python/site-packages (3.1.0)
# Requirement already satisfied: Werkzeug>=3.1 in /Users/jesuslopezguerrero/Library/Python/3.9/lib/python/site-packages (from Flask) (3.1.3)
# Requirement already satisfied: Jinja2>=3.1.2 in /Users/jesuslopezguerrero/Library/Python/3.9/lib/python/site-packages (from Flask) (3.1.5)
# Requirement already satisfied: itsdangerous>=2.2 in /Users/jesuslopezguerrero/Library/Python/3.9/lib/python/site-packages (from Flask) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in /Users/jesuslopezguerrero/Library/Python/3.9/lib/python/site-packages (from Flask) (8.1.8)
# Requirement already satisfied: blinker>=1.9 in /Users/jesuslopezguerrero/Library/Python/3.9/lib/python/site-packages (from Flask) (1.9.0)
# Requirement already satisfied: importlib-metadata>=3.6 in /Users/jesuslopezguerrero/Library/Python/3.9/lib/python/site-packages (from Flask) (8.5.0)
# Requirement already satisfied: zipp>=3.20 in /Users/jesuslopezguerrero/Library/Python/3.9/lib/python/site-packages (from importlib-metadata>=3.6->Flask) (3.21.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/jesuslopezguerrero/Library/Python/3.9/lib/python/site-packages (from Jinja2>=3.1.2->Flask) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install api.py
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: api.py in /Users/jesuslopezguerrero/Library/Python/3.9/lib/python/site-packages (0.0.1)
# Requirement already satisfied: argcomplete<2.0.0,>=1.11.0 in /Users/jesuslopezguerrero/Library/Python/3.9/lib/python/site-packages (from api.py) (1.12.3)
# Requirement already satisfied: future<0.19.0,>=0.18.2 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from api.py) (0.18.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.1 in /Users/jesuslopezguerrero/Library/Python/3.9/lib/python/site-packages (from api.py) (2.8.2)
# Requirement already satisfied: requests<3.0.0,>=2.22.0 in /Users/jesuslopezguerrero/Library/Python/3.9/lib/python/site-packages (from api.py) (2.32.3)
# Requirement already satisfied: requests-toolbelt<0.10.0,>=0.9.1 in /Users/jesuslopezguerrero/Library/Python/3.9/lib/python/site-packages (from api.py) (0.9.1)
# Requirement already satisfied: six<2.0.0,>=1.13.0 in /Users/jesuslopezguerrero/Library/Python/3.9/lib/python/site-packages (from api.py) (1.16.0)
# Requirement already satisfied: tabulate<0.9.0,>=0.8.6 in /Users/jesuslopezguerrero/Library/Python/3.9/lib/python/site-packages (from api.py) (0.8.10)
# Requirement already satisfied: tzlocal<3.0.0,>=2.0.0 in /Users/jesuslopezguerrero/Library/Python/3.9/lib/python/site-packages (from api.py) (2.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/jesuslopezguerrero/Library/Python/3.9/lib/python/site-packages (from requests<3.0.0,>=2.22.0->api.py) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/jesuslopezguerrero/Library/Python/3.9/lib/python/site-packages (from requests<3.0.0,>=2.22.0->api.py) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/jesuslopezguerrero/Library/Python/3.9/lib/python/site-packages (from requests<3.0.0,>=2.22.0->api.py) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/jesuslopezguerrero/Library/Python/3.9/lib/python/site-packages (from requests<3.0.0,>=2.22.0->api.py) (2024.12.14)
# Requirement already satisfied: pytz in /Users/jesuslopezguerrero/Library/Python/3.9/lib/python/site-packages (from tzlocal<3.0.0,>=2.0.0->api.py) (2022.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import json
from flask import Flask, jsonify, request

app = Flask(__name__)

# Lista global de empleados
employees = [
    {'id': 1, 'name': 'Ashley'},
    {'id': 2, 'name': 'Kate'},
    {'id': 3, 'name': 'Joe'}
]

nextEmployeeId = 4

# Obtener todos los empleados
@app.route('/employees', methods=['GET'])
def get_employees():
    return jsonify(employees)

def get_employee(id):
    return next((e for e in employees if e['id']==id), None)

def employee_is_valid(employee):
    for key in employee.keys():
        if key!='name':
            return False
        return True

@app.route('/employees', methods=['POST'])
def create_employee():
    global nextEmployeeId
    employee_is_valid=json.loads(request.data)
    if not employee_is_valid(employee):
        return jsonify({'error':'Invalid employee properties.'}), 400
    employee['id'] = nextEmployeeId
    nextEmployeeId += 1
    employees.append(employee)

    return '', 201, {'location': f'/employees/{employee["id"]}'}

@app.route('/employees/<int:id>', methods=['PUT'])
def update_employee(id: int):
    employee = get_employee(id)

    if employee is None:
        return jsonify({'error': 'Employee does not exist.'}), 404

    updated_employee = json.loads(request.data)

    if not employee_is_valid(updated_employee):
        return jsonify({'error': 'Invalid employee properties.'}), 400

    employee.update(updated_employee)
    return jsonify(employee)

if __name__ == '__main__':
    app.run(port=5000)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
